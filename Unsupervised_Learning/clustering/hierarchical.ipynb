# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples=30, centers=3, cluster_std=10, random_state=42)
X.shape
# Out:
# (30, 2)

# %%
plt.scatter(X[:,0] ,X[:,1])
plt.show()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Agglomerative Clustering

# %%
linked = linkage(X_scaled, method='ward')

plt.figure(figsize=(10, 5))
dendrogram(
    linked,
    truncate_mode='lastp',
    p=20
)
plt.title("Dendrogram")
plt.xlabel("Cluster Size")
plt.ylabel("Distance")
plt.show()

# %%
hc = AgglomerativeClustering(
    n_clusters=2,
    linkage='ward'
)

labels = hc.fit_predict(X_scaled)

# %%
plt.scatter(
    X_scaled[:, 0],
    X_scaled[:, 1],
    c=labels,
    s=20
)
plt.title("Hierarchical Clustering Result")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
x, y = make_moons(
    n_samples=500,
    noise=0.1,
    random_state=42
)

# %%
scaler = StandardScaler()
X_scaled_m = scaler.fit_transform(x)

# %%
linked = linkage(X_scaled_m, method='ward')

plt.figure(figsize=(10, 5))
dendrogram(
    linked,
    truncate_mode='lastp',
    p=20
)
plt.title("Dendrogram")
plt.xlabel("Cluster Size")
plt.ylabel("Distance")
plt.show()

# %%
hc = AgglomerativeClustering(
    n_clusters=2,
    linkage='ward'
)

labels = hc.fit_predict(X_scaled_m)

# %%
plt.scatter(
    X_scaled_m[:, 0],
    X_scaled_m[:, 1],
    c=labels,
    s=20
)
plt.title("Hierarchical Clustering Result")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# Here for moon dataset hierarchical clustering perform not that well because it use differnet method to form cluster than DBSCAN.
